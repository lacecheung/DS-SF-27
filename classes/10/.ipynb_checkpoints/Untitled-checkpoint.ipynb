# %%
import os

import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', 10)
pd.set_option('display.notebook_repr_html', True)

import statsmodels.formula.api as smf
import seaborn as sns

from sklearn import linear_model, cross_validation

# %matplotlib inline

# %%
df = pd.read_csv(os.path.join('datasets', 'abalone.csv'))

# %%
df
# Out:
#      Sex  Length  Diameter  Height  WholeWeight  ShuckedWeight  VisceraWeight  \
# 0      M   0.455     0.365   0.095       0.5140         0.2245         0.1010
# 1      M   0.350     0.265   0.090       0.2255         0.0995         0.0485
# 2      F   0.530     0.420   0.135       0.6770         0.2565         0.1415
# 3      M   0.440     0.365   0.125       0.5160         0.2155         0.1140
# 4      I   0.330     0.255   0.080       0.2050         0.0895         0.0395
# ...   ..     ...       ...     ...          ...            ...            ...
# 4172   F   0.565     0.450   0.165       0.8870         0.3700         0.2390
# 4173   M   0.590     0.440   0.135       0.9660         0.4390         0.2145
# 4174   M   0.600     0.475   0.205       1.1760         0.5255         0.2875
# 4175   F   0.625     0.485   0.150       1.0945         0.5310         0.2610
# 4176   M   0.710     0.555   0.195       1.9485         0.9455         0.3765
#
#       ShellWeight  Rings
# ...

# %%
df.columns
# Out:
# Index([u'Sex', u'Length', u'Diameter', u'Height', u'WholeWeight',
#        u'ShuckedWeight', u'VisceraWeight', u'ShellWeight', u'Rings'],
#       dtype='object')

# %%
df.info()
# no none null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
# Sex              4177 non-null object
# Length           4177 non-null float64
# Diameter         4177 non-null float64
# Height           4177 non-null float64
# WholeWeight      4177 non-null float64
# ShuckedWeight    4177 non-null float64
# VisceraWeight    4177 non-null float64
# ShellWeight      4177 non-null float64
# Rings            4177 non-null int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
df.describe()
# Out:
#             Length     Diameter       Height  WholeWeight  ShuckedWeight  \
# count  4177.000000  4177.000000  4177.000000  4177.000000    4177.000000
# mean      0.523992     0.407881     0.139516     0.828742       0.359367
# std       0.120093     0.099240     0.041827     0.490389       0.221963
# min       0.075000     0.055000     0.000000     0.002000       0.001000
# 25%       0.450000     0.350000     0.115000     0.441500       0.186000
# 50%       0.545000     0.425000     0.140000     0.799500       0.336000
# 75%       0.615000     0.480000     0.165000     1.153000       0.502000
# max       0.815000     0.650000     1.130000     2.825500       1.488000
#
#        VisceraWeight  ShellWeight        Rings
# count    4177.000000  4177.000000  4177.000000
# mean        0.180594     0.238831     9.933684
# std         0.109614     0.139203     3.224169
# min         0.000500     0.001500     1.000000
# 25%         0.093500     0.130000     8.000000
# ...

# %%
X = df.drop("Sex", axis = 1)

# %%
X
# Out:
#       Length  Diameter  Height  WholeWeight  ShuckedWeight  VisceraWeight  \
# 0      0.455     0.365   0.095       0.5140         0.2245         0.1010
# 1      0.350     0.265   0.090       0.2255         0.0995         0.0485
# 2      0.530     0.420   0.135       0.6770         0.2565         0.1415
# 3      0.440     0.365   0.125       0.5160         0.2155         0.1140
# 4      0.330     0.255   0.080       0.2050         0.0895         0.0395
# ...      ...       ...     ...          ...            ...            ...
# 4172   0.565     0.450   0.165       0.8870         0.3700         0.2390
# 4173   0.590     0.440   0.135       0.9660         0.4390         0.2145
# 4174   0.600     0.475   0.205       1.1760         0.5255         0.2875
# 4175   0.625     0.485   0.150       1.0945         0.5310         0.2610
# 4176   0.710     0.555   0.195       1.9485         0.9455         0.3765
#
#       ShellWeight  Rings
# 0          0.1500     15
# 1          0.0700      7
# ...

# %%
y = df.Sex

# %%
X_train, X_test, y_train, y_test = cross_validation.train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
X_train.shape[0]
# Out:
# 3341

# %%
X_test.shape[0]
# Out:
# 836

# %%
y_train.shape[0]
# Out:
# 3341L

# %%
y_test.shape[0]
# Out:
# 836L

# %%
X_train.corr()

#We see that these dimensions are highly correlated, so we are choosing to use just length, diameter and rings as our model features
# Out:
#                  Length  Diameter    Height  WholeWeight  ShuckedWeight  \
# Length         1.000000  0.986626  0.809545     0.925283       0.898074
# Diameter       0.986626  1.000000  0.815144     0.924761       0.892732
# Height         0.809545  0.815144  1.000000     0.802585       0.761996
# WholeWeight    0.925283  0.924761  0.802585     1.000000       0.969501
# ShuckedWeight  0.898074  0.892732  0.761996     0.969501       1.000000
# VisceraWeight  0.901923  0.898102  0.780910     0.965920       0.932480
# ShellWeight    0.896668  0.903953  0.799362     0.953238       0.879739
# Rings          0.551926  0.569614  0.533590     0.535350       0.414353
#
#                VisceraWeight  ShellWeight     Rings
# Length              0.901923     0.896668  0.551926
# Diameter            0.898102     0.903953  0.569614
# Height              0.780910     0.799362  0.533590
# WholeWeight         0.965920     0.953238  0.535350
# ShuckedWeight       0.932480     0.879739  0.414353
# ...

# %%
color_wheel = {"I": "red",
               "M": "blue",
               "F": "green"}

color = y_train.map(color_wheel)

pd.tools.plotting.scatter_matrix(X_train[['Length', 'Height', 'Rings']], c=color, s=70, figsize = (10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000DB52198>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001104C2B0>]], dtype=object)

# %%
features = X_train[["Height", "Length", "Rings", "WholeWeight"]]
c = y_train

model = linear_model.LogisticRegression().\
    fit(features, c)

# %%
model.score(features, c)
# Out:
# 0.54265190062855428

# %%
c_hat = model.predict(features)

# %%
pd.crosstab(c_hat,
    c,
    rownames = ['Hypothesized Class'],
    colnames = ['True Class'])
# Out:
# True Class            F    I    M
# Hypothesized Class
# F                    70    7   64
# I                   186  858  283
# M                   802  186  885

# %%
# We were able to identify the majority of infants, but the model could not separate M from Fs. 
# This makes sense from what we can see in the plots

# %%
#lets try it with all the features added back

features_2 = X_train
c = y_train

model = linear_model.LogisticRegression().\
    fit(features_2, c)
    
model.score(features_2, c)
# Out:
# 0.55402574079616884

# %%
c_hat_2 = model.predict(features_2)

pd.crosstab(c_hat_2,
    c,
    rownames = ['Hypothesized Class'],
    colnames = ['True Class'])
# Out:
# True Class            F    I    M
# Hypothesized Class
# F                   257   32  215
# I                   185  863  286
# M                   616  156  731

# %%
# Better performance than before!

# %%
# Are we including too many colinear variables? let's try it with just Height and Rings. 

features_3 = X_train[["Length", "Rings"]]
c = y_train

model = linear_model.LogisticRegression().\
    fit(features_3, c)
    
model.score(features_3, c)
# Out:
# 0.51900628554325057

# %%
y_dummy = pd.get_dummies(y_train, prefix = None)

# %%
y_dummy
# Out:
#         F    I    M
# 3141  0.0  1.0  0.0
# 3521  0.0  1.0  0.0
# 883   0.0  0.0  1.0
# 3627  0.0  0.0  1.0
# 2106  0.0  0.0  1.0
# ...   ...  ...  ...
# 1033  0.0  0.0  1.0
# 3264  1.0  0.0  0.0
# 1653  0.0  0.0  1.0
# 2607  1.0  0.0  0.0
# 2732  0.0  1.0  0.0
#
# [3341 rows x 3 columns]
