# %%
import os

import math

import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 20)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 10)

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
df = pd.read_csv(os.path.join(".", "datasets", "storms.csv.gz"))
df = df.set_index("REFNUM")
# Out:
# C:\Users\lacheung\AppData\Local\Continuum\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2723: DtypeWarning: Columns (2,9,10,11,12,16,17,27,28,29,30,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head(5)
# Out:
#         STATE__            BGN_DATE BGN_TIME TIME_ZONE  COUNTY   ...    \
# REFNUM                                                           ...
# 1.0         1.0   4/18/1950 0:00:00      130       CST    97.0   ...
# 2.0         1.0   4/18/1950 0:00:00      145       CST     3.0   ...
# 3.0         1.0   2/20/1951 0:00:00     1600       CST    57.0   ...
# 4.0         1.0    6/8/1951 0:00:00      900       CST    89.0   ...
# 5.0         1.0  11/15/1951 0:00:00     1500       CST    43.0   ...
#
#        LATITUDE LONGITUDE LATITUDE_E  LONGITUDE_ REMARKS
# REFNUM
# 1.0      3040.0    8812.0     3051.0      8806.0     NaN
# 2.0      3042.0    8755.0        0.0         0.0     NaN
# 3.0      3340.0    8742.0        0.0         0.0     NaN
# 4.0      3458.0    8626.0        0.0         0.0     NaN
# 5.0      3412.0    8642.0        0.0         0.0     NaN
#
# [5 rows x 36 columns]

# %%
df.columns.unique()
# Out:
# array(['STATE__', 'BGN_DATE', 'BGN_TIME', 'TIME_ZONE', 'COUNTY',
#        'COUNTYNAME', 'STATE', 'EVTYPE', 'BGN_RANGE', 'BGN_AZI',
#        'BGN_LOCATI', 'END_DATE', 'END_TIME', 'COUNTY_END', 'COUNTYENDN',
#        'END_RANGE', 'END_AZI', 'END_LOCATI', 'LENGTH', 'WIDTH', 'F', 'MAG',
#        'FATALITIES', 'INJURIES', 'PROPDMG', 'PROPDMGEXP', 'CROPDMG',
#        'CROPDMGEXP', 'WFO', 'STATEOFFIC', 'ZONENAMES', 'LATITUDE',
#        'LONGITUDE', 'LATITUDE_E', 'LONGITUDE_', 'REMARKS'], dtype=object)

# %%
df.shape
# Out:
# (902297, 36)

# %%
df.describe()
# Out:
# C:\Users\lacheung\AppData\Local\Continuum\Anaconda2\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#              STATE__         COUNTY      BGN_RANGE  COUNTY_END  COUNTYENDN  \
# count  902297.000000  902297.000000  902297.000000    902297.0         0.0
# mean       31.200958     100.642905       1.483889         0.0         NaN
# std        16.570178     107.276509       5.481574         0.0         NaN
# min         1.000000       0.000000       0.000000         0.0         NaN
# 25%        19.000000      31.000000       0.000000         0.0         NaN
# 50%        30.000000      75.000000       0.000000         0.0         NaN
# 75%        45.000000     131.000000       1.000000         0.0         NaN
# max        95.000000     873.000000    3749.000000         0.0         NaN
#
#            ...              CROPDMG       LATITUDE      LONGITUDE  \
# count      ...        902297.000000  902250.000000  902297.000000
# mean       ...             1.527022    2874.942950    6939.538350
# std        ...            22.173680    1657.648801    3958.062506
# min        ...             0.000000       0.000000  -14451.000000
# 25%        ...             0.000000            NaN    7247.000000
# 50%        ...             0.000000            NaN    8707.000000
# 75%        ...             0.000000            NaN    9605.000000
# max        ...           990.000000    9706.000000   17124.000000
#
#           LATITUDE_E     LONGITUDE_
# count  902257.000000  902297.000000
# mean     1451.611545    3509.139732
# std      1858.727873    4475.682973
# min         0.000000  -14455.000000
# 25%              NaN       0.000000
# 50%              NaN       0.000000
# 75%              NaN    8735.000000
# max      9706.000000  106220.000000
#
# [8 rows x 18 columns]

# %%
df.isnull().sum() / len(df) * 100.
# Out:
# STATE__        0.000000
# BGN_DATE       0.000000
# BGN_TIME       0.000000
# TIME_ZONE      0.000000
# COUNTY         0.000000
# COUNTYNAME     0.176106
# STATE          0.000000
# EVTYPE         0.000000
# BGN_RANGE      0.000000
# BGN_AZI       60.659849
#                 ...
# CROPDMG        0.000000
# CROPDMGEXP    68.537632
# WFO           15.745259
# STATEOFFIC    27.570634
# ZONENAMES     65.835196
# LATITUDE       0.005209
# LONGITUDE      0.000000
# LATITUDE_E     0.004433
# LONGITUDE_     0.000000
# REMARKS       31.855697
# dtype: float64

# %%
df.EVTYPE.unique()
# Out:
# array(['TORNADO', 'TSTM WIND', 'HAIL', 'FREEZING RAIN', 'SNOW',
#        'ICE STORM/FLASH FLOOD', 'SNOW/ICE', 'WINTER STORM',
#        'HURRICANE OPAL/HIGH WINDS', 'THUNDERSTORM WINDS', 'RECORD COLD',
#        'HURRICANE ERIN', 'HURRICANE OPAL', 'HEAVY RAIN', 'LIGHTNING',
#        'THUNDERSTORM WIND', 'DENSE FOG', 'RIP CURRENT',
#        'THUNDERSTORM WINS', 'FLASH FLOOD', 'FLASH FLOODING', 'HIGH WINDS',
#        'FUNNEL CLOUD', 'TORNADO F0', 'THUNDERSTORM WINDS LIGHTNING',
#        'THUNDERSTORM WINDS/HAIL', 'HEAT', 'WIND', 'LIGHTING',
#        'HEAVY RAINS', 'LIGHTNING AND HEAVY RAIN', 'FUNNEL', 'WALL CLOUD',
#        'FLOODING', 'THUNDERSTORM WINDS HAIL', 'FLOOD', 'COLD',
#        'HEAVY RAIN/LIGHTNING', 'FLASH FLOODING/THUNDERSTORM WI',
#        'WALL CLOUD/FUNNEL CLOUD', 'THUNDERSTORM', 'WATERSPOUT',
#        'EXTREME COLD', 'HAIL 1.75)', 'LIGHTNING/HEAVY RAIN', 'HIGH WIND',
#        'BLIZZARD', 'BLIZZARD WEATHER', 'WIND CHILL', 'BREAKUP FLOODING',
#        'HIGH WIND/BLIZZARD', 'RIVER FLOOD', 'HEAVY SNOW', 'FREEZE',
#        'COASTAL FLOOD', 'HIGH WIND AND HIGH TIDES',
#        'HIGH WIND/BLIZZARD/FREEZING RA', 'HIGH TIDES',
#        'HIGH WIND AND HEAVY SNOW', 'RECORD COLD AND HIGH WIND',
#        'RECORD HIGH TEMPERATURE', 'RECORD HIGH', 'HIGH WINDS HEAVY RAINS',
#        'HIGH WIND/ BLIZZARD', 'ICE STORM', 'BLIZZARD/HIGH WIND',
#        'HIGH WIND/LOW WIND CHILL', 'HEAVY SNOW/HIGH', 'RECORD LOW',
#        'HIGH WINDS AND WIND CHILL', 'HEAVY SNOW/HIGH WINDS/FREEZING',
#        'LOW TEMPERATURE RECORD', 'AVALANCHE', 'MARINE MISHAP',
#        'WIND CHILL/HIGH WIND', 'HIGH WIND/WIND CHILL/BLIZZARD',
#        'HIGH WIND/WIND CHILL', 'HIGH WIND/HEAVY SNOW',
#        'HIGH TEMPERATURE RECORD', 'FLOOD WATCH/',
#        'RECORD HIGH TEMPERATURES', 'HIGH WIND/SEAS',
#        'HIGH WINDS/HEAVY RAIN', 'HIGH SEAS', 'SEVERE TURBULENCE',
#        'RECORD RAINFALL', 'RECORD SNOWFALL', 'RECORD WARMTH',
#        'HEAVY SNOW/WIND', 'EXTREME HEAT', 'WIND DAMAGE', 'DUST STORM',
#        'APACHE COUNTY', 'SLEET', 'HAIL STORM', 'FUNNEL CLOUDS',
#        'FLASH FLOODS', 'DUST DEVIL', 'EXCESSIVE HEAT',
#        'THUNDERSTORM WINDS/FUNNEL CLOU', 'WINTER STORM/HIGH WIND',
#        'WINTER STORM/HIGH WINDS', 'GUSTY WINDS', 'STRONG WINDS',
#        'FLOODING/HEAVY RAIN', 'SNOW AND WIND',
#        'HEAVY SURF COASTAL FLOODING', 'HEAVY SURF', 'HEAVY PRECIPATATION',
#        'URBAN FLOODING', 'HIGH SURF', 'BLOWING DUST', 'URBAN/SMALL',
#        'WILD FIRES', 'HIGH', 'URBAN/SMALL FLOODING', 'WATER SPOUT',
#        'HIGH WINDS DUST STORM', 'WINTER STORM HIGH WINDS', 'LOCAL FLOOD',
#        'WINTER STORMS', 'MUDSLIDES', 'RAINSTORM', 'SEVERE THUNDERSTORM',
#        'SEVERE THUNDERSTORMS', 'SEVERE THUNDERSTORM WINDS',
#        'THUNDERSTORMS WINDS', 'DRY MICROBURST', 'FLOOD/FLASH FLOOD',
#        'FLOOD/RAIN/WINDS', 'WINDS', 'DRY MICROBURST 61', 'THUNDERSTORMS',
#        'FLASH FLOOD WINDS', 'URBAN/SMALL STREAM FLOODING', 'MICROBURST',
#        'STRONG WIND', 'HIGH WIND DAMAGE', 'STREAM FLOODING',
#        'URBAN AND SMALL', 'HEAVY SNOWPACK', 'ICE', 'FLASH FLOOD/',
#        'DOWNBURST', 'GUSTNADO AND', 'FLOOD/RAIN/WIND', 'WET MICROBURST',
#        'DOWNBURST WINDS', 'DRY MICROBURST WINDS', 'DRY MIRCOBURST WINDS',
#        'DRY MICROBURST 53', 'SMALL STREAM URBAN FLOOD', 'MICROBURST WINDS',
#        'HIGH WINDS 57', 'DRY MICROBURST 50', 'HIGH WINDS 66',
#        'HIGH WINDS 76', 'HIGH WINDS 63', 'HIGH WINDS 67',
#        'BLIZZARD/HEAVY SNOW', 'HEAVY SNOW/HIGH WINDS', 'BLOWING SNOW',
#        'HIGH WINDS 82', 'HIGH WINDS 80', 'HIGH WINDS 58',
#        'FREEZING DRIZZLE', 'LIGHTNING THUNDERSTORM WINDSS',
#        'DRY MICROBURST 58', 'HAIL 75', 'HIGH WINDS 73', 'HIGH WINDS 55',
#        'LIGHT SNOW AND SLEET', 'URBAN FLOOD', 'DRY MICROBURST 84',
#        'THUNDERSTORM WINDS 60', 'HEAVY RAIN/FLOODING',
#        'THUNDERSTORM WINDSS', 'TORNADOS', 'GLAZE', 'RECORD HEAT',
#        'COASTAL FLOODING', 'HEAT WAVE', 'FIRST SNOW',
#        'FREEZING RAIN AND SLEET', 'UNSEASONABLY DRY', 'UNSEASONABLY WET',
#        'WINTRY MIX', 'WINTER WEATHER', 'UNSEASONABLY COLD',
#        'EXTREME/RECORD COLD', 'RIP CURRENTS HEAVY SURF', 'SLEET/RAIN/SNOW',
#        'UNSEASONABLY WARM', 'DROUGHT', 'NORMAL PRECIPITATION',
#        'HIGH WINDS/FLOODING', 'DRY', 'RAIN/SNOW', 'SNOW/RAIN/SLEET',
#        'WATERSPOUT/TORNADO', 'WATERSPOUTS', 'WATERSPOUT TORNADO',
#        'URBAN/SMALL STREAM FLOOD', 'STORM SURGE', 'WATERSPOUT-TORNADO',
#        'WATERSPOUT-', 'TORNADOES, TSTM WIND, HAIL',
#        'TROPICAL STORM ALBERTO', 'TROPICAL STORM', 'TROPICAL STORM GORDON',
#        'TROPICAL STORM JERRY', 'LIGHTNING THUNDERSTORM WINDS',
#        'WAYTERSPOUT', 'MINOR FLOODING', 'LIGHTNING INJURY',
#        'URBAN/SMALL STREAM  FLOOD', 'LIGHTNING AND THUNDERSTORM WIN',
#        'THUNDERSTORM WINDS53', 'URBAN AND SMALL STREAM FLOOD',
#        'URBAN AND SMALL STREAM', 'WILDFIRE', 'DAMAGING FREEZE',
#        'THUNDERSTORM WINDS 13', 'SMALL HAIL', 'HEAVY SNOW/HIGH WIND',
#        'HURRICANE', 'WILD/FOREST FIRE', 'SMALL STREAM FLOODING',
#        'MUD SLIDE', 'LIGNTNING', 'FROST', 'FREEZING RAIN/SNOW',
#        'HIGH WINDS/', 'THUNDERSNOW', 'FLOODS', 'EXTREME WIND CHILLS',
#        'COOL AND WET', 'HEAVY RAIN/SNOW', 'SMALL STREAM AND URBAN FLOODIN',
#        'SMALL STREAM/URBAN FLOOD', 'SNOW/SLEET/FREEZING RAIN',
#        'SEVERE COLD', 'GLAZE ICE', 'COLD WAVE', 'EARLY SNOW',
#        'SMALL STREAM AND URBAN FLOOD', 'HIGH  WINDS', 'RURAL FLOOD',
#        'SMALL STREAM AND', 'MUD SLIDES', 'HAIL 80', 'EXTREME WIND CHILL',
#        'COLD AND WET CONDITIONS', 'EXCESSIVE WETNESS', 'GRADIENT WINDS',
#        'HEAVY SNOW/BLOWING SNOW', 'SLEET/ICE STORM',
#        'THUNDERSTORM WINDS URBAN FLOOD', 'THUNDERSTORM WINDS SMALL STREA',
#        'ROTATING WALL CLOUD', 'LARGE WALL CLOUD', 'COLD AIR FUNNEL',
#        'GUSTNADO', 'COLD AIR FUNNELS', 'BLOWING SNOW- EXTREME WIND CHI',
#        'SNOW AND HEAVY SNOW', 'GROUND BLIZZARD', 'MAJOR FLOOD',
#        'SNOW/HEAVY SNOW', 'FREEZING RAIN/SLEET', 'ICE JAM FLOODING',
#        'SNOW- HIGH WIND- WIND CHILL', 'STREET FLOOD', 'COLD AIR TORNADO',
#        'SMALL STREAM FLOOD', 'FOG', 'THUNDERSTORM WINDS 2',
#        'FUNNEL CLOUD/HAIL', 'ICE/SNOW', 'TSTM WIND 51', 'TSTM WIND 50',
#        'TSTM WIND 52', 'TSTM WIND 55', 'HEAVY SNOW/BLIZZARD',
#        'THUNDERSTORM WINDS 61', 'HAIL 0.75', 'THUNDERSTORM DAMAGE',
#        'THUNDERTORM WINDS', 'HAIL 1.00', 'HAIL/WINDS', 'SNOW AND ICE',
#        'WIND STORM', 'SNOWSTORM', 'GRASS FIRES', 'LAKE FLOOD',
#        'PROLONG COLD', 'HAIL/WIND', 'HAIL 1.75', 'THUNDERSTORMW 50',
#        'WIND/HAIL', 'SNOW AND ICE STORM', 'URBAN AND SMALL STREAM FLOODIN',
#        'THUNDERSTORMS WIND', 'THUNDERSTORM  WINDS', 'HEAVY SNOW/SLEET',
#        'AGRICULTURAL FREEZE', 'DROUGHT/EXCESSIVE HEAT', 'TUNDERSTORM WIND',
#        'TROPICAL STORM DEAN', 'THUNDERTSORM WIND',
#        'THUNDERSTORM WINDS/ HAIL', 'THUNDERSTORM WIND/LIGHTNING',
#        'HEAVY RAIN/SEVERE WEATHER', 'THUNDESTORM WINDS',
#        'WATERSPOUT/ TORNADO', 'LIGHTNING.', 'WARM DRY CONDITIONS',
#        'HURRICANE-GENERATED SWELLS', 'HEAVY SNOW/ICE STORM',
#        'RIVER AND STREAM FLOOD', 'HIGH WIND 63', 'COASTAL SURGE',
#        'HEAVY SNOW AND ICE STORM', 'MINOR FLOOD',
#        'HIGH WINDS/COASTAL FLOOD', 'RAIN', 'RIVER FLOODING', 'SNOW/RAIN',
#        'ICE FLOES', 'HIGH WAVES', 'SNOW SQUALLS', 'SNOW SQUALL',
#        'THUNDERSTORM WIND G50', 'LIGHTNING FIRE', 'BLIZZARD/FREEZING RAIN',
#        'HEAVY LAKE SNOW', 'HEAVY SNOW/FREEZING RAIN', 'LAKE EFFECT SNOW',
#        'HEAVY WET SNOW', 'DUST DEVIL WATERSPOUT',
#        'THUNDERSTORM WINDS/HEAVY RAIN', 'THUNDERSTROM WINDS',
#        'THUNDERSTORM WINDS      LE CEN', 'HAIL 225',
#        'BLIZZARD AND HEAVY SNOW', 'HEAVY SNOW AND ICE',
#        'ICE STORM AND SNOW', 'HEAVY SNOW ANDBLOWING SNOW',
#        'HEAVY SNOW/ICE', 'BLIZZARD AND EXTREME WIND CHIL',
#        'LOW WIND CHILL', 'BLOWING SNOW & EXTREME WIND CH', 'WATERSPOUT/',
#        'URBAN/SMALL STREAM', 'TORNADO F3', 'FUNNEL CLOUD.', 'TORNDAO',
#        'HAIL 0.88', 'FLOOD/RIVER FLOOD', 'MUD SLIDES URBAN FLOODING',
#        'TORNADO F1', 'THUNDERSTORM WINDS G', 'DEEP HAIL',
#        'GLAZE/ICE STORM', 'HEAVY SNOW/WINTER STORM', 'AVALANCE',
#        'BLIZZARD/WINTER STORM', 'DUST STORM/HIGH WINDS', 'ICE JAM',
#        'FOREST FIRES', 'THUNDERSTORM WIND G60', 'FROST\\FREEZE',
#        'THUNDERSTORM WINDS.', 'HAIL 88', 'HAIL 175', 'HVY RAIN',
#        'HAIL 100', 'HAIL 150', 'HAIL 075', 'THUNDERSTORM WIND G55',
#        'HAIL 125', 'THUNDERSTORM WINDS G60', 'HARD FREEZE', 'HAIL 200',
#        'THUNDERSTORM WINDS FUNNEL CLOU', 'THUNDERSTORM WINDS 62',
#        'WILDFIRES', 'RECORD HEAT WAVE', 'HEAVY SNOW AND HIGH WINDS',
#        'HEAVY SNOW/HIGH WINDS & FLOOD', 'HAIL FLOODING',
#        'THUNDERSTORM WINDS/FLASH FLOOD', 'HIGH WIND 70', 'WET SNOW',
#        'HEAVY RAIN AND FLOOD', 'LOCAL FLASH FLOOD',
#        'THUNDERSTORM WINDS 53', 'FLOOD/FLASH FLOODING',
#        'TORNADO/WATERSPOUT', 'RAIN AND WIND', 'THUNDERSTORM WIND 59',
#        'THUNDERSTORM WIND 52', 'COASTAL/TIDAL FLOOD', 'SNOW/ICE STORM',
#        'BELOW NORMAL PRECIPITATION', 'RIP CURRENTS/HEAVY SURF',
#        'FLASH FLOOD/FLOOD', 'EXCESSIVE RAIN', 'RECORD/EXCESSIVE HEAT',
#        'HEAT WAVES', 'LIGHT SNOW', 'THUNDERSTORM WIND 69', 'HAIL DAMAGE',
#        'LIGHTNING DAMAGE', 'RECORD TEMPERATURES', 'LIGHTNING AND WINDS',
#        'FOG AND COLD TEMPERATURES', 'OTHER', 'RECORD SNOW', 'SNOW/COLD',
#        'FLASH FLOOD FROM ICE JAMS', 'TSTM WIND G58', 'MUDSLIDE',
#        'HEAVY SNOW SQUALLS', 'HEAVY SNOW/SQUALLS', 'HEAVY SNOW-SQUALLS',
#        'ICY ROADS', 'HEAVY MIX', 'SNOW FREEZING RAIN', 'LACK OF SNOW',
#        'SNOW/SLEET', 'SNOW/FREEZING RAIN', 'SNOW DROUGHT',
#        'THUNDERSTORMW WINDS', 'THUNDERSTORM WIND 60 MPH',
#        'THUNDERSTORM WIND 65MPH', 'THUNDERSTORM WIND/ TREES',
#        'THUNDERSTORM WIND/AWNING', 'THUNDERSTORM WIND 98 MPH',
#        'THUNDERSTORM WIND TREES', 'TORRENTIAL RAIN', 'TORNADO F2',
#        'RIP CURRENTS', 'HURRICANE EMILY', 'HURRICANE GORDON',
#        'HURRICANE FELIX', 'THUNDERSTORM WIND 59 MPH',
#        'THUNDERSTORM WINDS 63 MPH', 'THUNDERSTORM WIND/ TREE',
#        'THUNDERSTORM DAMAGE TO', 'THUNDERSTORM WIND 65 MPH',
#        'FLASH FLOOD - HEAVY RAIN', 'THUNDERSTORM WIND.',
#        'FLASH FLOOD/ STREET', 'THUNDERSTORM WIND 59 MPH.',
#        'HEAVY SNOW   FREEZING RAIN', 'DAM FAILURE', 'THUNDERSTORM HAIL',
#        'HAIL 088', 'THUNDERSTORM WINDSHAIL', 'LIGHTNING  WAUSEON',
#        'THUDERSTORM WINDS', 'ICE AND SNOW', 'RECORD COLD/FROST',
#        'STORM FORCE WINDS', 'FREEZING RAIN AND SNOW',
#        'FREEZING RAIN SLEET AND', 'SOUTHEAST', 'HEAVY SNOW & ICE',
#        'FREEZING DRIZZLE AND FREEZING', 'THUNDERSTORM WINDS AND',
#        'HAIL/ICY ROADS', 'FLASH FLOOD/HEAVY RAIN',
#        'HEAVY RAIN; URBAN FLOOD WINDS;', 'HEAVY PRECIPITATION',
#        'TSTM WIND DAMAGE', 'HIGH WATER', 'FLOOD FLASH', 'RAIN/WIND',
#        'THUNDERSTORM WINDS 50', 'THUNDERSTORM WIND G52',
#        'FLOOD FLOOD/FLASH', 'THUNDERSTORM WINDS 52', 'SNOW SHOWERS',
#        'THUNDERSTORM WIND G51', 'HEAT WAVE DROUGHT',
#        'HEAVY SNOW/BLIZZARD/AVALANCHE', 'RECORD SNOW/COLD', 'WET WEATHER',
#        'UNSEASONABLY WARM AND DRY', 'FREEZING RAIN SLEET AND LIGHT',
#        'RECORD/EXCESSIVE RAINFALL', 'TIDAL FLOOD', 'BEACH EROSIN',
#        'THUNDERSTORM WIND G61', 'FLOOD/FLASH', 'LOW TEMPERATURE',
#        'SLEET & FREEZING RAIN', 'HEAVY RAINS/FLOODING',
#        'THUNDERESTORM WINDS', 'THUNDERSTORM WINDS/FLOODING',
#        'THUNDEERSTORM WINDS', 'HIGHWAY FLOODING', 'THUNDERSTORM W INDS',
#        'HYPOTHERMIA', 'FLASH FLOOD/ FLOOD', 'THUNDERSTORM WIND 50',
#        'THUNERSTORM WINDS', 'HEAVY RAIN/MUDSLIDES/FLOOD', 'MUD/ROCK SLIDE',
#        'HIGH WINDS/COLD', 'BEACH EROSION/COASTAL FLOOD', 'COLD/WINDS',
#        'SNOW/ BITTER COLD', 'THUNDERSTORM WIND 56', 'SNOW SLEET',
#        'DRY HOT WEATHER', 'COLD WEATHER', 'RAPIDLY RISING WATER',
#        'HAIL ALOFT', 'EARLY FREEZE', 'ICE/STRONG WINDS',
#        'EXTREME WIND CHILL/BLOWING SNO', 'SNOW/HIGH WINDS',
#        'HIGH WINDS/SNOW', 'EARLY FROST', 'SNOWMELT FLOODING',
#        'HEAVY SNOW AND STRONG WINDS', 'SNOW ACCUMULATION',
#        'BLOWING SNOW/EXTREME WIND CHIL', 'SNOW/ ICE', 'SNOW/BLOWING SNOW',
#        'TORNADOES', 'THUNDERSTORM WIND/HAIL', 'FLASH FLOODING/FLOOD',
#        'HAIL 275', 'HAIL 450', 'FLASH FLOOODING', 'EXCESSIVE RAINFALL',
#        'THUNDERSTORMW', 'HAILSTORM', 'TSTM WINDS', 'BEACH FLOOD',
#        'HAILSTORMS', 'TSTMW', 'FUNNELS', 'TSTM WIND 65)',
#        'THUNDERSTORM WINDS/ FLOOD', 'HEAVY RAINFALL', 'HEAT/DROUGHT',
#        'HEAT DROUGHT', 'NEAR RECORD SNOW', 'LANDSLIDE',
#        'HIGH WIND AND SEAS', 'THUNDERSTORMWINDS',
#        'THUNDERSTORM WINDS HEAVY RAIN', 'SLEET/SNOW', 'EXCESSIVE',
#        'SNOW/SLEET/RAIN', 'WILD/FOREST FIRES', 'HEAVY SEAS', 'DUSTSTORM',
#        'FLOOD & HEAVY RAIN', '?', 'THUNDERSTROM WIND', 'FLOOD/FLASHFLOOD',
#        'SNOW AND COLD', 'HOT PATTERN', 'PROLONG COLD/SNOW', 'BRUSH FIRES',
#        'SNOW\\COLD', 'WINTER MIX', 'EXCESSIVE PRECIPITATION',
#        'SNOWFALL RECORD', 'HOT/DRY PATTERN', 'DRY PATTERN',
#        'MILD/DRY PATTERN', 'MILD PATTERN', 'LANDSLIDES', 'HEAVY SHOWERS',
#        'HEAVY SNOW AND', 'HIGH WIND 48', 'LAKE-EFFECT SNOW', 'BRUSH FIRE',
#        'WATERSPOUT FUNNEL CLOUD', 'URBAN SMALL STREAM FLOOD',
#        'SAHARAN DUST', 'HEAVY SHOWER', 'URBAN FLOOD LANDSLIDE',
#        'HEAVY SWELLS', 'URBAN SMALL', 'URBAN FLOODS', 'SMALL STREAM',
#        'HEAVY RAIN/URBAN FLOOD', 'FLASH FLOOD/LANDSLIDE',
#        'LANDSLIDE/URBAN FLOOD', 'HEAVY RAIN/SMALL STREAM URBAN',
#        'FLASH FLOOD LANDSLIDES', 'EXTREME WINDCHILL',
#        'URBAN/SML STREAM FLD', 'TSTM WIND/HAIL', 'Other',
#        'Record dry month', 'Temperature record', 'Minor Flooding',
#        'Ice jam flood (minor', 'High Wind', 'Tstm Wind', 'ROUGH SURF',
#        'Wind', 'Heavy Surf', 'Dust Devil', 'Wind Damage',
#        'Marine Accident', 'Snow', 'Freeze', 'Snow Squalls',
#        'Coastal Flooding', 'Heavy Rain', 'Strong Wind', 'COASTAL STORM',
#        'COASTALFLOOD', 'Erosion/Cstl Flood', 'Heavy Rain and Wind',
#        'Light Snow/Flurries', 'Wet Month', 'Wet Year', 'Tidal Flooding',
#        'River Flooding', 'Damaging Freeze', 'Beach Erosion', 'Hot and Dry',
#        'Flood/Flash Flood', 'Icy Roads', 'High Surf',
#        'Heavy Rain/High Surf', 'Thunderstorm Wind', 'Rain Damage',
#        'Unseasonable Cold', 'Early Frost', 'Wintry Mix', 'blowing snow',
#        'STREET FLOODING', 'Record Cold', 'Extreme Cold', 'Ice Fog',
#        'Excessive Cold', 'Torrential Rainfall', 'Freezing Rain',
#        'Landslump', 'Late-season Snowfall', 'Hurricane Edouard',
#        'Coastal Storm', 'Flood', 'HEAVY RAIN/WIND', 'TIDAL FLOODING',
#        'Winter Weather', 'Snow squalls', 'Strong Winds', 'Strong winds',
#        'RECORD WARM TEMPS.', 'Ice/Snow', 'Mudslide', 'Glaze',
#        'Extended Cold', 'Snow Accumulation', 'Freezing Fog',
#        'Drifting Snow', 'Whirlwind', 'Heavy snow shower', 'Heavy rain',
#        'LATE SNOW', 'Record May Snow', 'Record Winter Snow',
#        'Heavy Precipitation', ' COASTAL FLOOD', 'Record temperature',
#        'Light snow', 'Late Season Snowfall', 'Gusty Wind', 'small hail',
#        'Light Snow', 'MIXED PRECIP', 'Black Ice', 'Mudslides',
#        'Gradient wind', 'Snow and Ice', 'Freezing Spray', 'Summary Jan 17',
#        'Summary of March 14', 'Summary of March 23', 'Summary of March 24',
#        'Summary of April 3rd', 'Summary of April 12',
#        'Summary of April 13', 'Summary of April 21', 'Summary August 11',
#        'Summary of April 27', 'Summary of May 9-10', 'Summary of May 10',
#        'Summary of May 13', 'Summary of May 14', 'Summary of May 22 am',
#        'Summary of May 22 pm', 'Heatburst', 'Summary of May 26 am',
#        'Summary of May 26 pm', 'Metro Storm, May 26',
#        'Summary of May 31 am', 'Summary of May 31 pm', 'Summary of June 3',
#        'Summary of June 4', 'Summary June 5-6', 'Summary June 6',
#        'Summary of June 11', 'Summary of June 12', 'Summary of June 13',
#        'Summary of June 15', 'Summary of June 16', 'Summary June 18-19',
#        'Summary of June 23', 'Summary of June 24', 'Summary of June 30',
#        'Summary of July 2', 'Summary of July 3', 'Summary of July 11',
#        'Summary of July 22', 'Summary July 23-24', 'Summary of July 26',
#        'Summary of July 29', 'Summary of August 1', 'Summary August 2-3',
#        'Summary August 7', 'Summary August 9', 'Summary August 10',
#        'Summary August 17', 'Summary August 21', 'Summary August 28',
#        'Summary September 4', 'Summary September 20',
#        'Summary September 23', 'Summary Sept. 25-26',
#        'Summary: Oct. 20-21', 'Summary: October 31', 'Summary: Nov. 6-7',
#        'Summary: Nov. 16', 'Microburst', 'wet micoburst', 'Hail(0.75)',
#        'Funnel Cloud', 'Urban Flooding', 'No Severe Weather',
#        'Urban flood', 'Urban Flood', 'Cold', 'Summary of May 22',
#        'Summary of June 6', 'Summary August 4', 'Summary of June 10',
#        'Summary of June 18', 'Summary September 3', 'Summary: Sept. 18',
#        'Coastal Flood', 'coastal flooding', 'Small Hail',
#        'Record Temperatures', 'Light Snowfall', 'Freezing Drizzle',
#        'Gusty wind/rain', 'GUSTY WIND/HVY RAIN', 'Blowing Snow',
#        'Early snowfall', 'Monthly Snowfall', 'Record Heat',
#        'Seasonal Snowfall', 'Monthly Rainfall', 'Cold Temperature',
#        'Sml Stream Fld', 'Heat Wave', 'MUDSLIDE/LANDSLIDE', 'Saharan Dust',
#        'Volcanic Ash', 'Volcanic Ash Plume', 'Thundersnow shower', 'NONE',
#        'COLD AND SNOW', 'DAM BREAK', 'TSTM WIND (G45)',
#        'SLEET/FREEZING RAIN', 'BLACK ICE', 'BLOW-OUT TIDES',
#        'UNSEASONABLY COOL', 'TSTM HEAVY RAIN', 'Gusty Winds', 'GUSTY WIND',
#        'TSTM WIND 40', 'TSTM WIND 45', 'TSTM WIND (41)', 'TSTM WIND (G40)',
#        'TSTM WND', 'Wintry mix', ' TSTM WIND', 'Frost', 'Frost/Freeze',
#        'RAIN (HEAVY)', 'Record Warmth', 'Prolong Cold', 'Cold and Frost',
#        'URBAN/SML STREAM FLDG', 'STRONG WIND GUST', 'LATE FREEZE',
#        'BLOW-OUT TIDE', 'Hypothermia/Exposure', 'HYPOTHERMIA/EXPOSURE',
#        'Lake Effect Snow', 'Mixed Precipitation', 'Record High',
#        'COASTALSTORM', 'Snow and sleet', 'Freezing rain', 'Gusty winds',
#        'Blizzard Summary', 'SUMMARY OF MARCH 24-25', 'SUMMARY OF MARCH 27',
#        'SUMMARY OF MARCH 29', 'GRADIENT WIND', 'Icestorm/Blizzard',
#        'Flood/Strong Wind', 'TSTM WIND AND LIGHTNING', 'gradient wind',
#        'Freezing drizzle', 'Mountain Snows', 'URBAN/SMALL STRM FLDG',
#        'Heavy surf and wind', 'Mild and Dry Pattern', 'COLD AND FROST',
#        'TYPHOON', 'HIGH SWELLS', 'HIGH  SWELLS', 'VOLCANIC ASH',
#        'DRY SPELL', ' LIGHTNING', 'BEACH EROSION', 'UNSEASONAL RAIN',
#        'EARLY RAIN', 'PROLONGED RAIN', 'WINTERY MIX',
#        'COASTAL FLOODING/EROSION', 'HOT SPELL', 'UNSEASONABLY HOT',
#        ' TSTM WIND (G45)', 'TSTM WIND  (G45)', 'HIGH WIND (G40)',
#        'TSTM WIND (G35)', 'DRY WEATHER', 'ABNORMAL WARMTH',
#        'UNUSUAL WARMTH', 'WAKE LOW WIND', 'MONTHLY RAINFALL',
#        'COLD TEMPERATURES', 'COLD WIND CHILL TEMPERATURES',
#        'MODERATE SNOW', 'MODERATE SNOWFALL', 'URBAN/STREET FLOODING',
#        'COASTAL EROSION', 'UNUSUAL/RECORD WARMTH', 'BITTER WIND CHILL',
#        'BITTER WIND CHILL TEMPERATURES', 'SEICHE', 'TSTM',
#        'COASTAL  FLOODING/EROSION', 'UNSEASONABLY WARM YEAR',
#        'HYPERTHERMIA/EXPOSURE', 'ROCK SLIDE', 'ICE PELLETS',
#        'PATCHY DENSE FOG', 'RECORD COOL', 'RECORD WARM', 'HOT WEATHER',
#        'RECORD TEMPERATURE', 'TROPICAL DEPRESSION', 'VOLCANIC ERUPTION',
#        'COOL SPELL', 'WIND ADVISORY', 'GUSTY WIND/HAIL',
#        'RED FLAG FIRE WX', 'FIRST FROST', 'EXCESSIVELY DRY',
#        'SNOW AND SLEET', 'LIGHT SNOW/FREEZING PRECIP', 'VOG',
#        'MONTHLY PRECIPITATION', 'MONTHLY TEMPERATURE', 'RECORD DRYNESS',
#        'EXTREME WINDCHILL TEMPERATURES', 'MIXED PRECIPITATION',
#        'DRY CONDITIONS', 'REMNANTS OF FLOYD', 'EARLY SNOWFALL',
#        'FREEZING FOG', 'LANDSPOUT', 'DRIEST MONTH', 'RECORD  COLD',
#        'LATE SEASON HAIL', 'EXCESSIVE SNOW', 'DRYNESS',
#        'FLOOD/FLASH/FLOOD', 'WIND AND WAVE', 'LIGHT FREEZING RAIN',
#        ' WIND', 'MONTHLY SNOWFALL', 'RECORD PRECIPITATION', 'ICE ROADS',
#        'ROUGH SEAS', 'UNSEASONABLY WARM/WET', 'UNSEASONABLY COOL & WET',
#        'UNUSUALLY WARM', 'TSTM WIND G45', 'NON SEVERE HAIL',
#        'NON-SEVERE WIND DAMAGE', 'UNUSUALLY COLD', 'WARM WEATHER',
#        'LANDSLUMP', 'THUNDERSTORM WIND (G40)', 'UNSEASONABLY WARM & WET',
#        ' FLASH FLOOD', 'LOCALLY HEAVY RAIN', 'WIND GUSTS',
#        'UNSEASONAL LOW TEMP', 'HIGH SURF ADVISORY', 'LATE SEASON SNOW',
#        'GUSTY LAKE WIND', 'ABNORMALLY DRY', 'WINTER WEATHER MIX',
#        'RED FLAG CRITERIA', 'WND', 'CSTL FLOODING/EROSION', 'SMOKE',
#        ' WATERSPOUT', 'SNOW ADVISORY', 'EXTREMELY WET',
#        'UNUSUALLY LATE SNOW', 'VERY DRY', 'RECORD LOW RAINFALL',
#        'ROGUE WAVE', 'PROLONG WARMTH', 'ACCUMULATED SNOWFALL',
#        'FALLING SNOW/ICE', 'DUST DEVEL', 'NON-TSTM WIND', 'NON TSTM WIND',
#        'GUSTY THUNDERSTORM WINDS', 'PATCHY ICE', 'HEAVY RAIN EFFECTS',
#        'EXCESSIVE HEAT/DROUGHT', 'NORTHERN LIGHTS', 'MARINE TSTM WIND',
#        '   HIGH SURF ADVISORY', 'HAZARDOUS SURF', 'FROST/FREEZE',
#        'WINTER WEATHER/MIX', 'ASTRONOMICAL HIGH TIDE', 'WHIRLWIND',
#        'VERY WARM', 'ABNORMALLY WET', 'TORNADO DEBRIS',
#        'EXTREME COLD/WIND CHILL', 'ICE ON ROAD', 'DROWNING',
#        'GUSTY THUNDERSTORM WIND', 'MARINE HAIL', 'HIGH SURF ADVISORIES',
#        'HURRICANE/TYPHOON', 'HEAVY SURF/HIGH SURF', 'SLEET STORM',
#        'STORM SURGE/TIDE', 'COLD/WIND CHILL', 'MARINE HIGH WIND',
#        'TSUNAMI', 'DENSE SMOKE', 'LAKESHORE FLOOD',
#        'MARINE THUNDERSTORM WIND', 'MARINE STRONG WIND',
#        'ASTRONOMICAL LOW TIDE', 'VOLCANIC ASHFALL'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 902297 entries, 1.0 to 902297.0
# Data columns (total 36 columns):
# STATE__       902297 non-null float64
# BGN_DATE      902297 non-null object
# BGN_TIME      902297 non-null object
# TIME_ZONE     902297 non-null object
# COUNTY        902297 non-null float64
# COUNTYNAME    900708 non-null object
# STATE         902297 non-null object
# EVTYPE        902297 non-null object
# BGN_RANGE     902297 non-null float64
# BGN_AZI       354965 non-null object
# BGN_LOCATI    614554 non-null object
# END_DATE      658886 non-null object
# END_TIME      663319 non-null object
# COUNTY_END    902297 non-null float64
# COUNTYENDN    0 non-null float64
# END_RANGE     902297 non-null float64
# END_AZI       177460 non-null object
# END_LOCATI    403072 non-null object
# LENGTH        902297 non-null float64
# WIDTH         902297 non-null float64
# F             58734 non-null float64
# MAG           902297 non-null float64
# FATALITIES    902297 non-null float64
# INJURIES      902297 non-null float64
# PROPDMG       902297 non-null float64
# PROPDMGEXP    436363 non-null object
# CROPDMG       902297 non-null float64
# CROPDMGEXP    283884 non-null object
# WFO           760228 non-null object
# STATEOFFIC    653528 non-null object
# ZONENAMES     308268 non-null object
# LATITUDE      902250 non-null float64
# LONGITUDE     902297 non-null float64
# LATITUDE_E    902257 non-null float64
# LONGITUDE_    902297 non-null float64
# REMARKS       614864 non-null object
# dtypes: float64(18), object(18)
# memory usage: 254.7+ MB

# %%
df2 = [[(df.EVTYPE, df.FATALITIES)]]
print df2
# Out:
# [[(REFNUM
# 1.0                TORNADO
# 2.0                TORNADO
# 3.0                TORNADO
# 4.0                TORNADO
# 5.0                TORNADO
# 6.0                TORNADO
# 7.0                TORNADO
# 8.0                TORNADO
# 9.0                TORNADO
# 10.0               TORNADO
#                  ...
# 902288.0    WINTER WEATHER
# 902289.0      FROST/FREEZE
# 902290.0         HIGH WIND
# 902291.0    WINTER WEATHER
# 902292.0    WINTER WEATHER
# 902293.0         HIGH WIND
# 902294.0         HIGH WIND
# 902295.0         HIGH WIND
# 902296.0          BLIZZARD
# 902297.0        HEAVY SNOW
# Name: EVTYPE, dtype: object, REFNUM
# 1.0         0.0
# 2.0         0.0
# 3.0         0.0
# 4.0         0.0
# 5.0         0.0
# 6.0         0.0
# 7.0         0.0
# 8.0         0.0
# 9.0         1.0
# 10.0        0.0
#            ...
# 902288.0    0.0
# 902289.0    0.0
# 902290.0    0.0
# 902291.0    0.0
# 902292.0    0.0
# 902293.0    0.0
# 902294.0    0.0
# 902295.0    0.0
# 902296.0    0.0
# 902297.0    0.0
# Name: FATALITIES, dtype: float64)]]

# %%
df2 = df[["EVTYPE", "FATALITIES"]]

# %%
for event in df.EVTYPE.unique():
    print event
# Out:
# TORNADO
# TSTM WIND
# HAIL
# FREEZING RAIN
# SNOW
# ICE STORM/FLASH FLOOD
# SNOW/ICE
# WINTER STORM
# HURRICANE OPAL/HIGH WINDS
# THUNDERSTORM WINDS
# RECORD COLD
# HURRICANE ERIN
# HURRICANE OPAL
# HEAVY RAIN
# LIGHTNING
# THUNDERSTORM WIND
# DENSE FOG
# RIP CURRENT
# THUNDERSTORM WINS
# FLASH FLOOD
# FLASH FLOODING
# HIGH WINDS
# FUNNEL CLOUD
# TORNADO F0
# THUNDERSTORM WINDS LIGHTNING
# THUNDERSTORM WINDS/HAIL
# HEAT
# WIND
# LIGHTING
# HEAVY RAINS
# LIGHTNING AND HEAVY RAIN
# FUNNEL
# WALL CLOUD
# FLOODING
# THUNDERSTORM WINDS HAIL
# FLOOD
# COLD
# HEAVY RAIN/LIGHTNING
# FLASH FLOODING/THUNDERSTORM WI
# WALL CLOUD/FUNNEL CLOUD
# THUNDERSTORM
# WATERSPOUT
# EXTREME COLD
# HAIL 1.75)
# LIGHTNING/HEAVY RAIN
# HIGH WIND
# BLIZZARD
# BLIZZARD WEATHER
# WIND CHILL
# BREAKUP FLOODING
# HIGH WIND/BLIZZARD
# RIVER FLOOD
# HEAVY SNOW
# FREEZE
# COASTAL FLOOD
# HIGH WIND AND HIGH TIDES
# HIGH WIND/BLIZZARD/FREEZING RA
# HIGH TIDES
# HIGH WIND AND HEAVY SNOW
# RECORD COLD AND HIGH WIND
# RECORD HIGH TEMPERATURE
# RECORD HIGH
# HIGH WINDS HEAVY RAINS
# HIGH WIND/ BLIZZARD
# ICE STORM
# BLIZZARD/HIGH WIND
# HIGH WIND/LOW WIND CHILL
# HEAVY SNOW/HIGH
# RECORD LOW
# HIGH WINDS AND WIND CHILL
# HEAVY SNOW/HIGH WINDS/FREEZING
# LOW TEMPERATURE RECORD
# AVALANCHE
# MARINE MISHAP
# WIND CHILL/HIGH WIND
# HIGH WIND/WIND CHILL/BLIZZARD
# HIGH WIND/WIND CHILL
# HIGH WIND/HEAVY SNOW
# HIGH TEMPERATURE RECORD
# FLOOD WATCH/
# RECORD HIGH TEMPERATURES
# HIGH WIND/SEAS
# HIGH WINDS/HEAVY RAIN
# HIGH SEAS
# SEVERE TURBULENCE
# RECORD RAINFALL
# RECORD SNOWFALL
# RECORD WARMTH
# HEAVY SNOW/WIND
# EXTREME HEAT
# WIND DAMAGE
# DUST STORM
# APACHE COUNTY
# SLEET
# HAIL STORM
# FUNNEL CLOUDS
# FLASH FLOODS
# DUST DEVIL
# EXCESSIVE HEAT
# THUNDERSTORM WINDS/FUNNEL CLOU
# WINTER STORM/HIGH WIND
# WINTER STORM/HIGH WINDS
# GUSTY WINDS
# STRONG WINDS
# FLOODING/HEAVY RAIN
# SNOW AND WIND
# HEAVY SURF COASTAL FLOODING
# HEAVY SURF
# HEAVY PRECIPATATION
# URBAN FLOODING
# HIGH SURF
# BLOWING DUST
# URBAN/SMALL
# WILD FIRES
# HIGH
# URBAN/SMALL FLOODING
# WATER SPOUT
# HIGH WINDS DUST STORM
# WINTER STORM HIGH WINDS
# LOCAL FLOOD
# WINTER STORMS
# MUDSLIDES
# RAINSTORM
# SEVERE THUNDERSTORM
# SEVERE THUNDERSTORMS
# SEVERE THUNDERSTORM WINDS
# THUNDERSTORMS WINDS
# DRY MICROBURST
# FLOOD/FLASH FLOOD
# FLOOD/RAIN/WINDS
# WINDS
# DRY MICROBURST 61
# THUNDERSTORMS
# FLASH FLOOD WINDS
# URBAN/SMALL STREAM FLOODING
# MICROBURST
# STRONG WIND
# HIGH WIND DAMAGE
# STREAM FLOODING
# URBAN AND SMALL
# HEAVY SNOWPACK
# ICE
# FLASH FLOOD/
# DOWNBURST
# GUSTNADO AND
# FLOOD/RAIN/WIND
# WET MICROBURST
# DOWNBURST WINDS
# DRY MICROBURST WINDS
# DRY MIRCOBURST WINDS
# DRY MICROBURST 53
# SMALL STREAM URBAN FLOOD
# MICROBURST WINDS
# HIGH WINDS 57
# DRY MICROBURST 50
# HIGH WINDS 66
# HIGH WINDS 76
# HIGH WINDS 63
# HIGH WINDS 67
# BLIZZARD/HEAVY SNOW
# HEAVY SNOW/HIGH WINDS
# BLOWING SNOW
# HIGH WINDS 82
# HIGH WINDS 80
# HIGH WINDS 58
# FREEZING DRIZZLE
# LIGHTNING THUNDERSTORM WINDSS
# DRY MICROBURST 58
# HAIL 75
# HIGH WINDS 73
# HIGH WINDS 55
# LIGHT SNOW AND SLEET
# URBAN FLOOD
# DRY MICROBURST 84
# THUNDERSTORM WINDS 60
# HEAVY RAIN/FLOODING
# THUNDERSTORM WINDSS
# TORNADOS
# GLAZE
# RECORD HEAT
# COASTAL FLOODING
# HEAT WAVE
# FIRST SNOW
# FREEZING RAIN AND SLEET
# UNSEASONABLY DRY
# UNSEASONABLY WET
# WINTRY MIX
# WINTER WEATHER
# UNSEASONABLY COLD
# EXTREME/RECORD COLD
# RIP CURRENTS HEAVY SURF
# SLEET/RAIN/SNOW
# UNSEASONABLY WARM
# DROUGHT
# NORMAL PRECIPITATION
# HIGH WINDS/FLOODING
# DRY
# RAIN/SNOW
# SNOW/RAIN/SLEET
# WATERSPOUT/TORNADO
# WATERSPOUTS
# WATERSPOUT TORNADO
# URBAN/SMALL STREAM FLOOD
# STORM SURGE
# WATERSPOUT-TORNADO
# WATERSPOUT-
# TORNADOES, TSTM WIND, HAIL
# TROPICAL STORM ALBERTO
# TROPICAL STORM
# TROPICAL STORM GORDON
# TROPICAL STORM JERRY
# LIGHTNING THUNDERSTORM WINDS
# WAYTERSPOUT
# MINOR FLOODING
# LIGHTNING INJURY
# URBAN/SMALL STREAM  FLOOD
# LIGHTNING AND THUNDERSTORM WIN
# THUNDERSTORM WINDS53
# URBAN AND SMALL STREAM FLOOD
# URBAN AND SMALL STREAM
# WILDFIRE
# DAMAGING FREEZE
# THUNDERSTORM WINDS 13
# SMALL HAIL
# HEAVY SNOW/HIGH WIND
# HURRICANE
# WILD/FOREST FIRE
# SMALL STREAM FLOODING
# MUD SLIDE
# LIGNTNING
# FROST
# FREEZING RAIN/SNOW
# HIGH WINDS/
# THUNDERSNOW
# FLOODS
# EXTREME WIND CHILLS
# COOL AND WET
# HEAVY RAIN/SNOW
# SMALL STREAM AND URBAN FLOODIN
# SMALL STREAM/URBAN FLOOD
# SNOW/SLEET/FREEZING RAIN
# SEVERE COLD
# GLAZE ICE
# COLD WAVE
# EARLY SNOW
# SMALL STREAM AND URBAN FLOOD
# HIGH  WINDS
# RURAL FLOOD
# SMALL STREAM AND
# MUD SLIDES
# HAIL 80
# EXTREME WIND CHILL
# COLD AND WET CONDITIONS
# EXCESSIVE WETNESS
# GRADIENT WINDS
# HEAVY SNOW/BLOWING SNOW
# SLEET/ICE STORM
# THUNDERSTORM WINDS URBAN FLOOD
# THUNDERSTORM WINDS SMALL STREA
# ROTATING WALL CLOUD
# LARGE WALL CLOUD
# COLD AIR FUNNEL
# GUSTNADO
# COLD AIR FUNNELS
# BLOWING SNOW- EXTREME WIND CHI
# SNOW AND HEAVY SNOW
# GROUND BLIZZARD
# MAJOR FLOOD
# SNOW/HEAVY SNOW
# FREEZING RAIN/SLEET
# ICE JAM FLOODING
# SNOW- HIGH WIND- WIND CHILL
# STREET FLOOD
# COLD AIR TORNADO
# SMALL STREAM FLOOD
# FOG
# THUNDERSTORM WINDS 2
# FUNNEL CLOUD/HAIL
# ICE/SNOW
# TSTM WIND 51
# TSTM WIND 50
# TSTM WIND 52
# TSTM WIND 55
# HEAVY SNOW/BLIZZARD
# THUNDERSTORM WINDS 61
# HAIL 0.75
# THUNDERSTORM DAMAGE
# THUNDERTORM WINDS
# HAIL 1.00
# HAIL/WINDS
# SNOW AND ICE
# WIND STORM
# SNOWSTORM
# GRASS FIRES
# LAKE FLOOD
# PROLONG COLD
# HAIL/WIND
# HAIL 1.75
# THUNDERSTORMW 50
# WIND/HAIL
# SNOW AND ICE STORM
# URBAN AND SMALL STREAM FLOODIN
# THUNDERSTORMS WIND
# THUNDERSTORM  WINDS
# HEAVY SNOW/SLEET
# AGRICULTURAL FREEZE
# DROUGHT/EXCESSIVE HEAT
# TUNDERSTORM WIND
# TROPICAL STORM DEAN
# THUNDERTSORM WIND
# THUNDERSTORM WINDS/ HAIL
# THUNDERSTORM WIND/LIGHTNING
# HEAVY RAIN/SEVERE WEATHER
# THUNDESTORM WINDS
# WATERSPOUT/ TORNADO
# LIGHTNING.
# WARM DRY CONDITIONS
# HURRICANE-GENERATED SWELLS
# HEAVY SNOW/ICE STORM
# RIVER AND STREAM FLOOD
# HIGH WIND 63
# COASTAL SURGE
# HEAVY SNOW AND ICE STORM
# MINOR FLOOD
# HIGH WINDS/COASTAL FLOOD
# RAIN
# RIVER FLOODING
# SNOW/RAIN
# ICE FLOES
# HIGH WAVES
# SNOW SQUALLS
# SNOW SQUALL
# THUNDERSTORM WIND G50
# LIGHTNING FIRE
# BLIZZARD/FREEZING RAIN
# HEAVY LAKE SNOW
# HEAVY SNOW/FREEZING RAIN
# LAKE EFFECT SNOW
# HEAVY WET SNOW
# DUST DEVIL WATERSPOUT
# THUNDERSTORM WINDS/HEAVY RAIN
# THUNDERSTROM WINDS
# THUNDERSTORM WINDS      LE CEN
# HAIL 225
# BLIZZARD AND HEAVY SNOW
# HEAVY SNOW AND ICE
# ICE STORM AND SNOW
# HEAVY SNOW ANDBLOWING SNOW
# HEAVY SNOW/ICE
# BLIZZARD AND EXTREME WIND CHIL
# LOW WIND CHILL
# BLOWING SNOW & EXTREME WIND CH
# WATERSPOUT/
# URBAN/SMALL STREAM
# TORNADO F3
# FUNNEL CLOUD.
# TORNDAO
# HAIL 0.88
# FLOOD/RIVER FLOOD
# MUD SLIDES URBAN FLOODING
# TORNADO F1
# THUNDERSTORM WINDS G
# DEEP HAIL
# GLAZE/ICE STORM
# HEAVY SNOW/WINTER STORM
# AVALANCE
# BLIZZARD/WINTER STORM
# DUST STORM/HIGH WINDS
# ICE JAM
# FOREST FIRES
# THUNDERSTORM WIND G60
# FROST\FREEZE
# THUNDERSTORM WINDS.
# HAIL 88
# HAIL 175
# HVY RAIN
# HAIL 100
# HAIL 150
# HAIL 075
# THUNDERSTORM WIND G55
# HAIL 125
# THUNDERSTORM WINDS G60
# HARD FREEZE
# HAIL 200
# THUNDERSTORM WINDS FUNNEL CLOU
# THUNDERSTORM WINDS 62
# WILDFIRES
# RECORD HEAT WAVE
# HEAVY SNOW AND HIGH WINDS
# HEAVY SNOW/HIGH WINDS & FLOOD
# HAIL FLOODING
# THUNDERSTORM WINDS/FLASH FLOOD
# HIGH WIND 70
# WET SNOW
# HEAVY RAIN AND FLOOD
# LOCAL FLASH FLOOD
# THUNDERSTORM WINDS 53
# FLOOD/FLASH FLOODING
# TORNADO/WATERSPOUT
# RAIN AND WIND
# THUNDERSTORM WIND 59
# THUNDERSTORM WIND 52
# COASTAL/TIDAL FLOOD
# SNOW/ICE STORM
# BELOW NORMAL PRECIPITATION
# RIP CURRENTS/HEAVY SURF
# FLASH FLOOD/FLOOD
# EXCESSIVE RAIN
# RECORD/EXCESSIVE HEAT
# HEAT WAVES
# LIGHT SNOW
# THUNDERSTORM WIND 69
# HAIL DAMAGE
# LIGHTNING DAMAGE
# RECORD TEMPERATURES
# LIGHTNING AND WINDS
# FOG AND COLD TEMPERATURES
# OTHER
# RECORD SNOW
# SNOW/COLD
# FLASH FLOOD FROM ICE JAMS
# TSTM WIND G58
# MUDSLIDE
# HEAVY SNOW SQUALLS
# HEAVY SNOW/SQUALLS
# HEAVY SNOW-SQUALLS
# ICY ROADS
# HEAVY MIX
# SNOW FREEZING RAIN
# LACK OF SNOW
# SNOW/SLEET
# SNOW/FREEZING RAIN
# SNOW DROUGHT
# THUNDERSTORMW WINDS
# THUNDERSTORM WIND 60 MPH
# THUNDERSTORM WIND 65MPH
# THUNDERSTORM WIND/ TREES
# THUNDERSTORM WIND/AWNING
# THUNDERSTORM WIND 98 MPH
# THUNDERSTORM WIND TREES
# TORRENTIAL RAIN
# TORNADO F2
# RIP CURRENTS
# HURRICANE EMILY
# HURRICANE GORDON
# HURRICANE FELIX
# THUNDERSTORM WIND 59 MPH
# THUNDERSTORM WINDS 63 MPH
# THUNDERSTORM WIND/ TREE
# THUNDERSTORM DAMAGE TO
# THUNDERSTORM WIND 65 MPH
# FLASH FLOOD - HEAVY RAIN
# THUNDERSTORM WIND.
# FLASH FLOOD/ STREET
# THUNDERSTORM WIND 59 MPH.
# HEAVY SNOW   FREEZING RAIN
# DAM FAILURE
# THUNDERSTORM HAIL
# HAIL 088
# THUNDERSTORM WINDSHAIL
# LIGHTNING  WAUSEON
# THUDERSTORM WINDS
# ICE AND SNOW
# RECORD COLD/FROST
# STORM FORCE WINDS
# FREEZING RAIN AND SNOW
# FREEZING RAIN SLEET AND
# SOUTHEAST
# HEAVY SNOW & ICE
# FREEZING DRIZZLE AND FREEZING
# THUNDERSTORM WINDS AND
# HAIL/ICY ROADS
# FLASH FLOOD/HEAVY RAIN
# HEAVY RAIN; URBAN FLOOD WINDS;
# HEAVY PRECIPITATION
# TSTM WIND DAMAGE
# HIGH WATER
# FLOOD FLASH
# RAIN/WIND
# THUNDERSTORM WINDS 50
# THUNDERSTORM WIND G52
# FLOOD FLOOD/FLASH
# THUNDERSTORM WINDS 52
# SNOW SHOWERS
# THUNDERSTORM WIND G51
# HEAT WAVE DROUGHT
# HEAVY SNOW/BLIZZARD/AVALANCHE
# RECORD SNOW/COLD
# WET WEATHER
# UNSEASONABLY WARM AND DRY
# FREEZING RAIN SLEET AND LIGHT
# RECORD/EXCESSIVE RAINFALL
# TIDAL FLOOD
# BEACH EROSIN
# THUNDERSTORM WIND G61
# FLOOD/FLASH
# LOW TEMPERATURE
# SLEET & FREEZING RAIN
# HEAVY RAINS/FLOODING
# THUNDERESTORM WINDS
# THUNDERSTORM WINDS/FLOODING
# THUNDEERSTORM WINDS
# HIGHWAY FLOODING
# THUNDERSTORM W INDS
# HYPOTHERMIA
# FLASH FLOOD/ FLOOD
# THUNDERSTORM WIND 50
# THUNERSTORM WINDS
# HEAVY RAIN/MUDSLIDES/FLOOD
# MUD/ROCK SLIDE
# HIGH WINDS/COLD
# BEACH EROSION/COASTAL FLOOD
# COLD/WINDS
# SNOW/ BITTER COLD
# THUNDERSTORM WIND 56
# SNOW SLEET
# DRY HOT WEATHER
# COLD WEATHER
# RAPIDLY RISING WATER
# HAIL ALOFT
# EARLY FREEZE
# ICE/STRONG WINDS
# EXTREME WIND CHILL/BLOWING SNO
# SNOW/HIGH WINDS
# HIGH WINDS/SNOW
# EARLY FROST
# SNOWMELT FLOODING
# HEAVY SNOW AND STRONG WINDS
# SNOW ACCUMULATION
# BLOWING SNOW/EXTREME WIND CHIL
# SNOW/ ICE
# SNOW/BLOWING SNOW
# TORNADOES
# THUNDERSTORM WIND/HAIL
# FLASH FLOODING/FLOOD
# HAIL 275
# HAIL 450
# FLASH FLOOODING
# EXCESSIVE RAINFALL
# THUNDERSTORMW
# HAILSTORM
# TSTM WINDS
# BEACH FLOOD
# HAILSTORMS
# TSTMW
# FUNNELS
# TSTM WIND 65)
# THUNDERSTORM WINDS/ FLOOD
# HEAVY RAINFALL
# HEAT/DROUGHT
# HEAT DROUGHT
# NEAR RECORD SNOW
# LANDSLIDE
# HIGH WIND AND SEAS
# THUNDERSTORMWINDS
# THUNDERSTORM WINDS HEAVY RAIN
# SLEET/SNOW
# EXCESSIVE
# SNOW/SLEET/RAIN
# WILD/FOREST FIRES
# HEAVY SEAS
# DUSTSTORM
# FLOOD & HEAVY RAIN
# ?
# THUNDERSTROM WIND
# FLOOD/FLASHFLOOD
# SNOW AND COLD
# HOT PATTERN
# PROLONG COLD/SNOW
# BRUSH FIRES
# SNOW\COLD
# WINTER MIX
# EXCESSIVE PRECIPITATION
# SNOWFALL RECORD
# HOT/DRY PATTERN
# DRY PATTERN
# MILD/DRY PATTERN
# MILD PATTERN
# LANDSLIDES
# HEAVY SHOWERS
# HEAVY SNOW AND
# HIGH WIND 48
# LAKE-EFFECT SNOW
# BRUSH FIRE
# WATERSPOUT FUNNEL CLOUD
# URBAN SMALL STREAM FLOOD
# SAHARAN DUST
# HEAVY SHOWER
# URBAN FLOOD LANDSLIDE
# HEAVY SWELLS
# URBAN SMALL
# URBAN FLOODS
# SMALL STREAM
# HEAVY RAIN/URBAN FLOOD
# FLASH FLOOD/LANDSLIDE
# LANDSLIDE/URBAN FLOOD
# HEAVY RAIN/SMALL STREAM URBAN
# FLASH FLOOD LANDSLIDES
# EXTREME WINDCHILL
# URBAN/SML STREAM FLD
# TSTM WIND/HAIL
# Other
# Record dry month
# Temperature record
# Minor Flooding
# Ice jam flood (minor
# High Wind
# Tstm Wind
# ROUGH SURF
# Wind
# Heavy Surf
# Dust Devil
# Wind Damage
# Marine Accident
# Snow
# Freeze
# Snow Squalls
# Coastal Flooding
# Heavy Rain
# Strong Wind
# COASTAL STORM
# COASTALFLOOD
# Erosion/Cstl Flood
# Heavy Rain and Wind
# Light Snow/Flurries
# Wet Month
# Wet Year
# Tidal Flooding
# River Flooding
# Damaging Freeze
# Beach Erosion
# Hot and Dry
# Flood/Flash Flood
# Icy Roads
# High Surf
# Heavy Rain/High Surf
# Thunderstorm Wind
# Rain Damage
# Unseasonable Cold
# Early Frost
# Wintry Mix
# blowing snow
# STREET FLOODING
# Record Cold
# Extreme Cold
# Ice Fog
# Excessive Cold
# Torrential Rainfall
# Freezing Rain
# Landslump
# Late-season Snowfall
# Hurricane Edouard
# Coastal Storm
# Flood
# HEAVY RAIN/WIND
# TIDAL FLOODING
# Winter Weather
# Snow squalls
# Strong Winds
# Strong winds
# RECORD WARM TEMPS.
# Ice/Snow
# Mudslide
# Glaze
# Extended Cold
# Snow Accumulation
# Freezing Fog
# Drifting Snow
# Whirlwind
# Heavy snow shower
# Heavy rain
# LATE SNOW
# Record May Snow
# Record Winter Snow
# Heavy Precipitation
#  COASTAL FLOOD
# Record temperature
# Light snow
# Late Season Snowfall
# Gusty Wind
# small hail
# Light Snow
# MIXED PRECIP
# Black Ice
# Mudslides
# Gradient wind
# Snow and Ice
# Freezing Spray
# Summary Jan 17
# Summary of March 14
# Summary of March 23
# Summary of March 24
# Summary of April 3rd
# Summary of April 12
# Summary of April 13
# Summary of April 21
# Summary August 11
# Summary of April 27
# Summary of May 9-10
# Summary of May 10
# Summary of May 13
# Summary of May 14
# Summary of May 22 am
# Summary of May 22 pm
# Heatburst
# Summary of May 26 am
# Summary of May 26 pm
# Metro Storm, May 26
# Summary of May 31 am
# Summary of May 31 pm
# Summary of June 3
# Summary of June 4
# Summary June 5-6
# Summary June 6
# Summary of June 11
# Summary of June 12
# Summary of June 13
# Summary of June 15
# Summary of June 16
# Summary June 18-19
# Summary of June 23
# Summary of June 24
# Summary of June 30
# Summary of July 2
# Summary of July 3
# Summary of July 11
# Summary of July 22
# Summary July 23-24
# Summary of July 26
# Summary of July 29
# Summary of August 1
# Summary August 2-3
# Summary August 7
# Summary August 9
# Summary August 10
# Summary August 17
# Summary August 21
# Summary August 28
# Summary September 4
# Summary September 20
# Summary September 23
# Summary Sept. 25-26
# Summary: Oct. 20-21
# Summary: October 31
# Summary: Nov. 6-7
# Summary: Nov. 16
# Microburst
# wet micoburst
# Hail(0.75)
# Funnel Cloud
# Urban Flooding
# No Severe Weather
# Urban flood
# Urban Flood
# Cold
# Summary of May 22
# Summary of June 6
# Summary August 4
# Summary of June 10
# Summary of June 18
# Summary September 3
# Summary: Sept. 18
# Coastal Flood
# coastal flooding
# Small Hail
# Record Temperatures
# Light Snowfall
# Freezing Drizzle
# Gusty wind/rain
# GUSTY WIND/HVY RAIN
# Blowing Snow
# Early snowfall
# Monthly Snowfall
# Record Heat
# Seasonal Snowfall
# Monthly Rainfall
# Cold Temperature
# Sml Stream Fld
# Heat Wave
# MUDSLIDE/LANDSLIDE
# Saharan Dust
# Volcanic Ash
# Volcanic Ash Plume
# Thundersnow shower
# NONE
# COLD AND SNOW
# DAM BREAK
# TSTM WIND (G45)
# SLEET/FREEZING RAIN
# BLACK ICE
# BLOW-OUT TIDES
# UNSEASONABLY COOL
# TSTM HEAVY RAIN
# Gusty Winds
# GUSTY WIND
# TSTM WIND 40
# TSTM WIND 45
# TSTM WIND (41)
# TSTM WIND (G40)
# TSTM WND
# Wintry mix
#  TSTM WIND
# Frost
# Frost/Freeze
# RAIN (HEAVY)
# Record Warmth
# Prolong Cold
# Cold and Frost
# URBAN/SML STREAM FLDG
# STRONG WIND GUST
# LATE FREEZE
# BLOW-OUT TIDE
# Hypothermia/Exposure
# HYPOTHERMIA/EXPOSURE
# Lake Effect Snow
# Mixed Precipitation
# Record High
# COASTALSTORM
# Snow and sleet
# Freezing rain
# Gusty winds
# Blizzard Summary
# SUMMARY OF MARCH 24-25
# SUMMARY OF MARCH 27
# SUMMARY OF MARCH 29
# GRADIENT WIND
# Icestorm/Blizzard
# Flood/Strong Wind
# TSTM WIND AND LIGHTNING
# gradient wind
# Freezing drizzle
# Mountain Snows
# URBAN/SMALL STRM FLDG
# Heavy surf and wind
# Mild and Dry Pattern
# COLD AND FROST
# TYPHOON
# HIGH SWELLS
# HIGH  SWELLS
# VOLCANIC ASH
# DRY SPELL
#  LIGHTNING
# BEACH EROSION
# UNSEASONAL RAIN
# EARLY RAIN
# PROLONGED RAIN
# WINTERY MIX
# COASTAL FLOODING/EROSION
# HOT SPELL
# UNSEASONABLY HOT
#  TSTM WIND (G45)
# TSTM WIND  (G45)
# HIGH WIND (G40)
# TSTM WIND (G35)
# DRY WEATHER
# ABNORMAL WARMTH
# UNUSUAL WARMTH
# WAKE LOW WIND
# MONTHLY RAINFALL
# COLD TEMPERATURES
# COLD WIND CHILL TEMPERATURES
# MODERATE SNOW
# MODERATE SNOWFALL
# URBAN/STREET FLOODING
# COASTAL EROSION
# UNUSUAL/RECORD WARMTH
# BITTER WIND CHILL
# BITTER WIND CHILL TEMPERATURES
# SEICHE
# TSTM
# COASTAL  FLOODING/EROSION
# UNSEASONABLY WARM YEAR
# HYPERTHERMIA/EXPOSURE
# ROCK SLIDE
# ICE PELLETS
# PATCHY DENSE FOG
# RECORD COOL
# RECORD WARM
# HOT WEATHER
# RECORD TEMPERATURE
# TROPICAL DEPRESSION
# VOLCANIC ERUPTION
# COOL SPELL
# WIND ADVISORY
# GUSTY WIND/HAIL
# RED FLAG FIRE WX
# FIRST FROST
# EXCESSIVELY DRY
# SNOW AND SLEET
# LIGHT SNOW/FREEZING PRECIP
# VOG
# MONTHLY PRECIPITATION
# MONTHLY TEMPERATURE
# RECORD DRYNESS
# EXTREME WINDCHILL TEMPERATURES
# MIXED PRECIPITATION
# DRY CONDITIONS
# REMNANTS OF FLOYD
# EARLY SNOWFALL
# FREEZING FOG
# LANDSPOUT
# DRIEST MONTH
# RECORD  COLD
# LATE SEASON HAIL
# EXCESSIVE SNOW
# DRYNESS
# FLOOD/FLASH/FLOOD
# WIND AND WAVE
# LIGHT FREEZING RAIN
#  WIND
# MONTHLY SNOWFALL
# RECORD PRECIPITATION
# ICE ROADS
# ROUGH SEAS
# UNSEASONABLY WARM/WET
# UNSEASONABLY COOL & WET
# UNUSUALLY WARM
# TSTM WIND G45
# NON SEVERE HAIL
# NON-SEVERE WIND DAMAGE
# UNUSUALLY COLD
# WARM WEATHER
# LANDSLUMP
# THUNDERSTORM WIND (G40)
# UNSEASONABLY WARM & WET
#  FLASH FLOOD
# LOCALLY HEAVY RAIN
# WIND GUSTS
# UNSEASONAL LOW TEMP
# HIGH SURF ADVISORY
# LATE SEASON SNOW
# GUSTY LAKE WIND
# ABNORMALLY DRY
# WINTER WEATHER MIX
# RED FLAG CRITERIA
# WND
# CSTL FLOODING/EROSION
# SMOKE
#  WATERSPOUT
# SNOW ADVISORY
# EXTREMELY WET
# UNUSUALLY LATE SNOW
# VERY DRY
# RECORD LOW RAINFALL
# ROGUE WAVE
# PROLONG WARMTH
# ACCUMULATED SNOWFALL
# FALLING SNOW/ICE
# DUST DEVEL
# NON-TSTM WIND
# NON TSTM WIND
# GUSTY THUNDERSTORM WINDS
# PATCHY ICE
# HEAVY RAIN EFFECTS
# EXCESSIVE HEAT/DROUGHT
# NORTHERN LIGHTS
# MARINE TSTM WIND
#    HIGH SURF ADVISORY
# HAZARDOUS SURF
# FROST/FREEZE
# WINTER WEATHER/MIX
# ASTRONOMICAL HIGH TIDE
# WHIRLWIND
# VERY WARM
# ABNORMALLY WET
# TORNADO DEBRIS
# EXTREME COLD/WIND CHILL
# ICE ON ROAD
# DROWNING
# GUSTY THUNDERSTORM WIND
# MARINE HAIL
# HIGH SURF ADVISORIES
# HURRICANE/TYPHOON
# HEAVY SURF/HIGH SURF
# SLEET STORM
# STORM SURGE/TIDE
# COLD/WIND CHILL
# MARINE HIGH WIND
# TSUNAMI
# DENSE SMOKE
# LAKESHORE FLOOD
# MARINE THUNDERSTORM WIND
# MARINE STRONG WIND
# ASTRONOMICAL LOW TIDE
# VOLCANIC ASHFALL

# %%
df.EVTYPE = df.EVTYPE.str.lower()
df.EVTYPE = df.EVTYPE.str.strip()

# %%
df.EVTYPE.head(5)
# Out:
# REFNUM
# 1.0    tornado
# 2.0    tornado
# 3.0    tornado
# 4.0    tornado
# 5.0    tornado
# Name: EVTYPE, dtype: object

# %%
len(df.EVTYPE.unique())
# Out:
# 890

# %%
df = df[(df.FATALITIES>0) | (df.INJURIES>0)]

# %%
df.shape
# Out:
# (21929, 36)

# %%
len(df.EVTYPE.unique())
# Out:
# 205

# %%
(df.EVTYPE.value_counts() == 1).sum()
# Out:
# 96

# %%
df.EVTYPE.value_counts()
# Out:
# TORNADO                    7928
# LIGHTNING                  3305
# TSTM WIND                  2930
# FLASH FLOOD                 931
# THUNDERSTORM WIND           682
# EXCESSIVE HEAT              678
# HIGH WIND                   525
# FLOOD                       410
# RIP CURRENT                 399
# THUNDERSTORM WINDS          359
#                            ...
# TROPICAL STORM GORDON         1
# HIGH SWELLS                   1
# HYPOTHERMIA                   1
# WINTER STORM HIGH WINDS       1
# THUNDERTORM WINDS             1
# UNSEASONABLY COLD             1
# HEAVY SNOW SHOWER             1
# THUNDERSTORM WINDSS           1
# WIND STORM                    1
# WILD FIRES                    1
# Name: EVTYPE, dtype: int64

# %%
df2.plot.bar()

# %%
df2.plot.bar()

# %%
df2.plot.bar()

# %%
df['EVTYPE'] = df.EVTYPE.apply(lambda type: type.strip().upper())

 
official_event_types = [
   'Astronomical Low Tide', 'Avalanche',
   'Blizzard', 'Coastal Flood', 'Cold/Wind Chill', 'Debris Flow',
   'Dense Fog', 'Dense Smoke', 'Drought', 'Dust Devil', 'Dust Storm',
   'Excessive Heat', 'Extreme Cold/Wind Chill', 'Flash Flood', 'Flood',
   'Frost/Freeze', 'Funnel Cloud', 'Freezing Fog', 'Hail', 'Heat',
   'Heavy Rain', 'Heavy Snow', 'High Surf', 'High Wind',
   'Hurricane (Typhoon)', 'Ice Storm', 'Lake-Effect Snow',
   'Lakeshore Flood', 'Lightning', 'Marine Hail', 'Marine High Wind',
   'Marine Strong Wind', 'Marine Thunderstorm Wind', 'Rip Current',
   'Seiche', 'Sleet', 'Storm Surge/Tide', 'Strong Wind',
   'Thunderstorm Wind', 'Tornado', 'Tropical Depression',
   'Tropical Storm', 'Tsunami', 'Volcanic Ash', 'Waterspout', 'Wildfire',
   'Winter Storm', 'Winter Weather',

   # We are also adding 'OTHER'...
   'OTHER'
]

official_event_types = map(lambda type: type.upper(), official_event_types)

# %%
df.PROPDMGEXP.count_values()

# %%
df.PROPDMGEXP.plot(kind="hist")
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-6-503f9758cbf7> in <module>()
# ----> 1 df.PROPDMGEXP.plot(kind="hist")
#
# C:\Users\lacheung\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\tools\plotting.pyc in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    3564                            colormap=colormap, table=table, yerr=yerr,
#    3565                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 3566                            **kwds)
#    3567     __call__.__doc__ = plot_series.__doc__
#    3568
#
# C:\Users\lacheung\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\tools\plotting.pyc in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2643                  yerr=yerr, xerr=xerr,
#    2644                  label=label, secondary_y=secondary_y,
# -> 2645                  **kwds)
#    2646
#    2647
#
# C:\Users\lacheung\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\tools\plotting.pyc in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2439         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    2440
# -> 2441     plot_obj.generate()
#    2442     plot_obj.draw()
#    2443     return plot_obj.result
#
# C:\Users\lacheung\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\tools\plotting.pyc in generate(self)
#    1024     def generate(self):
#    1025         self._args_adjust()
# -> 1026         self._compute_plot_data()
#    1027         self._setup_subplots()
#    1028         self._make_plot()
#
# C:\Users\lacheung\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\tools\plotting.pyc in _compute_plot_data(self)
#    1133         if is_empty:
#    1134             raise TypeError('Empty {0!r}: no numeric data to '
# -> 1135                             'plot'.format(numeric_data.__class__.__name__))
#    1136
#    1137         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot
