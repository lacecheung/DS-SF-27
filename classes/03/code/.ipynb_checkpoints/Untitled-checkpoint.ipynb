# %%
import os

import math

import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 20)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 10)

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
df = pd.read_excel("practice_gallup.xlsx")
df.set_index("Name")
# Out:
#       woo  confidence  emphaty  organizer  communivator    ...     activator  \
# Name                                                       ...
# a     1.0         NaN      NaN        1.0           NaN    ...           NaN
# b     NaN         NaN      NaN        NaN           NaN    ...           1.0
# c     NaN         NaN      NaN        1.0           1.0    ...           NaN
# d     NaN         NaN      NaN        NaN           NaN    ...           1.0
# e     NaN         NaN      1.0        NaN           NaN    ...           1.0
# f     NaN         NaN      NaN        NaN           NaN    ...           1.0
# g     NaN         NaN      1.0        1.0           1.0    ...           NaN
# h     NaN         NaN      NaN        NaN           1.0    ...           1.0
# i     NaN         NaN      NaN        NaN           NaN    ...           NaN
# j     NaN         NaN      NaN        NaN           NaN    ...           NaN
# k     1.0         NaN      NaN        1.0           1.0    ...           NaN
# l     NaN         NaN      NaN        1.0           NaN    ...           1.0
# m     NaN         1.0      NaN        NaN           NaN    ...           1.0
# n     NaN         NaN      NaN        NaN           NaN    ...           NaN
# o     NaN         1.0      1.0        1.0           NaN    ...           NaN
# p     1.0         NaN      1.0        1.0           NaN    ...           NaN
#
#       analytical  connector  includer  listener
# Name
# a            1.0        NaN       NaN       NaN
# b            1.0        NaN       NaN       NaN
# c            NaN        NaN       NaN       NaN
# d            NaN        1.0       1.0       NaN
# e            1.0        NaN       NaN       NaN
# f            1.0        NaN       NaN       1.0
# g            NaN        NaN       NaN       NaN
# h            NaN        NaN       NaN       NaN
# i            1.0        NaN       1.0       NaN
# j            1.0        1.0       NaN       NaN
# k            NaN        NaN       NaN       NaN
# l            NaN        NaN       NaN       NaN
# m            1.0        NaN       NaN       NaN
# n            NaN        1.0       1.0       NaN
# o            NaN        NaN       NaN       NaN
# p            NaN        NaN       NaN       NaN
#
# [16 rows x 11 columns]

# %%
df.woo
# Out:
# 0     1.0
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    1.0
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    1.0
# Name: woo, dtype: float64
